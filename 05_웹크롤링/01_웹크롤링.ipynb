# %% [markdown]
# # 웹크롤링 - 멜론 사이트

# %%
# - 웹 브라우저를 조작..
# - 웹 브라우저에 보이는 HTML 태그속에서 
# - 텍스트 데이터를 분리해서 가지고 오는 
# selenium 설치명령 : conda install -c conda-forge selenium
# conda install로 설치가 안돠면 : pip install selenium
from selenium import webdriver

# %%
# 구글 드라이버 다운로드 하기
# https://sites.google.com/a/chromium.org/chromedriver/downloads

# %%
driver = webdriver.Chrome("C:/ChromeDriver_exe/chromedriver.exe")
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_13708/2815863721.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/ChromeDriver_exe/chromedriver.exe")

# %%
# 웹 url로 접근하기
url = "https://www.naver.com"
driver.get(url)

# %%
html = driver.page_source
html
# Out:
# '<html lang="ko" data-dark="false" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36"><head><script async="" type="text/javascript" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-core.js"></script> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"> <meta name="robots" content="index,nofollow"> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:u
# ...

# %%
# html 형태
html = '''
     <html>
        <head>
        </head>
        <body>
            <h1> 우리동네시장</h1>
                <div class = 'sale'>
                    <p id='fruits1' class='fruits'>
                        <span class = 'name'> 바나나 </span>
                        <span class = 'price'> 3000원 </span>
                        <span class = 'inventory'> 500개 </span>
                        <span class = 'store'> 가나다상회 </span>
                        <a href = 'http://bit.ly/forPlaywithData' > 홈페이지 </a>
                    </p>
                </div>
                <div class = 'prepare'>
                    <p id='fruits2' class='fruits'>
                        <span class ='name'> 파인애플 </span>
                    </p>
                </div>
        </body>
    </html>
 '''

# %%
html
# Out:
# "\n     <html>\n        <head>\n        </head>\n        <body>\n            <h1> 우리동네시장</h1>\n                <div class = 'sale'>\n                    <p id='fruits1' class='fruits'>\n                        <span class = 'name'> 바나나 </span>\n                        <span class = 'price'> 3000원 </span>\n                        <span class = 'inventory'> 500개 </span>\n                        <span class = 'store'> 가나다상회 </span>\n                        <a href = 'http://bit.ly/forPlaywithData' > 홈페이지 </a>\n                    </p>\n                </div>\n                <div class = 'prepare'>\n                    <p id='fruits2' class='fruits'>\n                        <span class ='name'> 파인애플 </span>\n                    </p>\n                </div>\n        </body>\n    </html>\n "

# %%
# BeautifulSoup
# - 문자열 데이터를 HTML 형식으로 읽어들이고,
# - 정보를 쉽게 찾을 수 있도록 도와주는 라이브러리...
# - HTML 문서를 해석합니다.
from bs4 import BeautifulSoup

# %%
# html.parser
# 문자열 형태의 html 문서를 실제 html 형태로 변환
soup = BeautifulSoup(html, "html.parser")

# %%
soup
# Out:
# <html>
# <head>
# </head>
# <body>
# <h1> 우리동네시장</h1>
# <div class="sale">
# <p class="fruits" id="fruits1">
# <span class="name"> 바나나 </span>
# <span class="price"> 3000원 </span>
# <span class="inventory"> 500개 </span>
# <span class="store"> 가나다상회 </span>
# <a href="http://bit.ly/forPlaywithData"> 홈페이지 </a>
# </p>
# </div>
# <div class="prepare">
# <p class="fruits" id="fruits2">
# <span class="name"> 파인애플 </span>
# </p>
# </div>
# </body>
# </html>

# %%
tags_span=soup.select("span")
tags_span
# Out:
# [<span class="name"> 바나나 </span>,
#  <span class="price"> 3000원 </span>,
#  <span class="inventory"> 500개 </span>,
#  <span class="store"> 가나다상회 </span>,
#  <span class="name"> 파인애플 </span>]

# %%
tags_p = soup.select("p")
tags_p
# Out:
# [<p class="fruits" id="fruits1">
#  <span class="name"> 바나나 </span>
#  <span class="price"> 3000원 </span>
#  <span class="inventory"> 500개 </span>
#  <span class="store"> 가나다상회 </span>
#  <a href="http://bit.ly/forPlaywithData"> 홈페이지 </a>
#  </p>,
#  <p class="fruits" id="fruits2">
#  <span class="name"> 파인애플 </span>
#  </p>]

# %%
# class는 .   ,  고유 id 는 #
ids_fruits1 = soup.select("#fruits1")
ids_fruits1
# Out:
# [<p class="fruits" id="fruits1">
#  <span class="name"> 바나나 </span>
#  <span class="price"> 3000원 </span>
#  <span class="inventory"> 500개 </span>
#  <span class="store"> 가나다상회 </span>
#  <a href="http://bit.ly/forPlaywithData"> 홈페이지 </a>
#  </p>]

# %%
# class 속성을 컨트롤 할 때, 점(.)을 사용
# 같은 값이 여러개 있을 수 있습니다.
class_price=soup.select(".price")
class_price
# Out:
# [<span class="price"> 3000원 </span>]

# %%
soup.select("span.name")
# Out:
# [<span class="name"> 바나나 </span>, <span class="name"> 파인애플 </span>]

# %%
# 태그 구조 중에 자식/자손 의미를 부여하는 기호..
# 자식 : 직계
# 자손 : 내 밑으로 전체

# id 속성이 fruits1인 값을 가지는 자식 중에
# span이라는 태그의 속성 중 클래스 이름이 name인 태그를 조회...
soup.select("#fruits1 > span.name")
# Out:
# [<span class="name"> 바나나 </span>]

# %%
# div 태그의 클래스 속성의 이름이 sale인 자식 중에
# id의 이름이 fruits1 인 태그의 자식을 찾아서
# span 태그의 클래스 속성이 name인 태그를 조회해 주세요...
soup.select("div.sale>#fruits1 > span.name")
# Out:
# [<span class="name"> 바나나 </span>]

# %%
# 띄어쓰기는 자손을 의미
soup.select("div.sale span.name")
# Out:
# [<span class="name"> 바나나 </span>]

# %%
tags =soup.select("span.name")
tags
# Out:
# [<span class="name"> 바나나 </span>, <span class="name"> 파인애플 </span>]

# %%
tags[1]
# Out:
# <span class="name"> 파인애플 </span>

# %%
#  값을 이용하는 방식 , 리스트 튜플 딕셔너리 여라가지 형태가 다들어있을떄의 메모리 형태를 인덱스번호 자동체크  (구두를 필기로함.)
for t in tags : 
    print (t)
# Out:
# <span class="name"> 바나나 </span>
# <span class="name"> 파인애플 </span>

# %%
# range 범위 0부터 len의 사이즈 -1 만큼 돈다(간격은 1).
for i in range(0 ,len(tags), 1) : 
    print (tags[i])
# Out:
# <span class="name"> 바나나 </span>
# <span class="name"> 파인애플 </span>

# %%
tag
# Out:
# <span class="name"> 파인애플 </span>

# %%
tag.text
# Out:
# ' 파인애플 '

# %%
# 리스트형태
t_list=tag["class"]
t_list
# Out:
# ['name']

# %%
# 값만 나타냄
t_list2=tag["class"][0]
t_list2
# Out:
# 'name'

# %%
# a태그 사용하기 ..... 링크값을 가지고 있습니다.
# a태그 조회....
tags =soup.select("a")
tags
# Out:
# [<a href="http://bit.ly/forPlaywithData"> 홈페이지 </a>]

# %%
tag =tags[0]
tag
# Out:
# <a href="http://bit.ly/forPlaywithData"> 홈페이지 </a>

# %%
tag.text
# Out:
# ' 홈페이지 '

# %%
# url 링크주소
tag["href"]
# Out:
# 'http://bit.ly/forPlaywithData'

# %% [markdown]
# # 멜론 노래 순위 정보 클로링 하기...

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome("C:/ChromeDriver_exe/chromedriver.exe")
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_13708/2815863721.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/ChromeDriver_exe/chromedriver.exe")

# %%
url = "http://www.melon.com/chart/index.htm"
driver.get(url)

# %%
from bs4 import BeautifulSoup

# %%
html = driver.page_source
html
# Out:
# '<html lang="ko" class="narrow-screen"><head>\n\t\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\n\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\t\n\n\t\n\n\t\n\n\t<title>멜론차트&gt;TOP100&gt;멜론</title>\n\t<meta name="keywords" content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널">\n\t<meta name="description" content="No.1 뮤직플랫폼 멜론! 최신 트렌드부터 나를 아는 똑똑한 음악추천까지!">\n\t<meta name="naver-site-verification" content="ee85ff6db1fa8f2226bcb671ecb2bcdbcffb6f8b">\n\t<meta name="google-site-verification" content="q4tbTQhmxa4La3OdNLsNOCxrJ_WV6lUlBFrFW4-HqQc">\n\t<meta property="fb:app_id" content="357952407588971">\n\t<meta property="og:title" content="Melon">\n\t<meta property="og:image" content="https://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png">\n\t<meta property="og:description" content="음악이 필요한 순간, 멜론">\n\t<meta property="og:url" content="http://www.melon.com/ch
# ...

# %%
# html.parser
# 문자열 형태의 html 문서를 실제 html 형태로 변환
soup = BeautifulSoup(html, "html.parser")
soup
# Out:
# <html class="narrow-screen" lang="ko"><head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>멜론차트&gt;TOP100&gt;멜론</title>
# <meta content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널" name="keywords"/>
# <meta content="No.1 뮤직플랫폼 멜론! 최신 트렌드부터 나를 아는 똑똑한 음악추천까지!" name="description"/>
# <meta content="ee85ff6db1fa8f2226bcb671ecb2bcdbcffb6f8b" name="naver-site-verification"/>
# <meta content="q4tbTQhmxa4La3OdNLsNOCxrJ_WV6lUlBFrFW4-HqQc" name="google-site-verification"/>
# <meta content="357952407588971" property="fb:app_id"/>
# <meta content="Melon" property="og:title"/>
# <meta content="https://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png" property="og:image"/>
# <meta content="음악이 필요한 순간, 멜론" property="og:description"/>
# <meta content="http://www.melon.com/chart/index.htm" property="og:url"/>
# ...

# %%
songs =soup.select("tr")
songs
# Out:
# [<tr>
#  <th scope="col">
#  <div class="wrap t_right"><input class="input_check d_checkall" title="곡 목록 전체 선택" type="checkbox"/></div>
#  </th>
#  <th scope="col">
#  <div class="wrap t_center"><span class="rank">순위</span></div>
#  </th>
#  <th scope="col">
#  <div class="wrap none">순위등락</div>
#  </th>
#  <th scope="col">
#  <div class="wrap none">앨범이미지</div>
#  </th>
#  <th scope="col">
#  <div class="wrap none">곡 상세가기</div>
#  </th>
#  <th scope="col">
#  <div class="wrap pd_l_12">곡정보</div>
#  </th>
#  <th scope="col">
#  <div class="wrap pd_l_12">앨범</div>
#  </th>
#  <th scope="col">
#  <div class="wrap pd_l_30">좋아요</div>
#  </th>
#  <th scope="col">
#  <div class="wrap t_center">듣기</div>
#  </th>
#  <th scope="col">
#  <div class="wrap t_center">담기</div>
#  </th>
#  <th scope="col">
#  <div class="wrap t_center">다운</div>
#  </th>
#  <th scope="col">
#  <div class="wrap t_center">뮤비</div>
#  </th>
#  </tr>,
#  <tr class="lst50" data-song-no="34626109" id="lst50">
# ...

# %%
soup.select("tr")[1]
# Out:
# <tr class="lst50" data-song-no="34626109" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="INVU 곡 선택" type="checkbox" value="34626109"/></div></td>
# <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10863559');" title="INVU - The 3rd Album">
# <img alt="INVU - The 3rd Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/108/63/559/10863559_20220214160739_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# ...

# %%
len(songs)
# Out:
# 101

# %%
# 리스트에서 범위 지정

songs = soup.select("tr")[1 : ]
len(songs)
# Out:
# 100

# %%
song = songs[0]
song
# Out:
# <tr class="lst50" data-song-no="34626109" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="INVU 곡 선택" type="checkbox" value="34626109"/></div></td>
# <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10863559');" title="INVU - The 3rd Album">
# <img alt="INVU - The 3rd Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/108/63/559/10863559_20220214160739_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# ...

# %%
song.select("a")
# Out:
# [<a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10863559');" title="INVU - The 3rd Album">
#  <img alt="INVU - The 3rd Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/108/63/559/10863559_20220214160739_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('34626109');" title="INVU 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('1000002721',34626109);" title="INVU 재생">INVU</a>,
#  <a href="javascript:melon.link.goArtistDetail('236797');" title="태연 (TAEYEON) - 페이지 이동">태연 (TAEYEON)</a>,
#  <a href="javascript:melon.link.goArtistDetail('236797');" title="태연 (TAEYEON) - 페이지 이동">태연 (TAEYEON)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10863559');" title="INVU - The 3rd Album - 페이지 이동">INVU - The 3rd Album</a>]

# %% [markdown]
# ### 가수리스트 추출

# %%
singer = soup.select("span.checkEllipsis")
singer
for i in singer:
    print(i.text)
# Out:
# 태연 (TAEYEON)
# 임영웅
# 김민석 (멜로망스)
# MSG워너비(M.O.M)
# 케이시 (Kassy)
# STAYC(스테이씨)
# GAYLE
# IVE (아이브)
# 휘인 (Whee In)
# YENA (최예나)
# GOT the beat
# sokodomo
# 경서예지, 전건호
# 임영웅
# BE'O (비오)
# 탑현
# 이무진
# 이무진
# The Kid LAROI, Justin Bieber
# 임영웅
# BE'O (비오)
# 임영웅
# 폴킴
# 임영웅
# aespa
# 아이유
# aespa
# 임영웅
# 임영웅
# 멜로망스
# 태연 (TAEYEON)
# 노을
# 아이유
# 임영웅
# 태연 (TAEYEON)
# 방탄소년단
# 방탄소년단
# aespa
# 아이유
# 비투비
# MSG워너비(M.O.M)
# 주시크 (Joosiq)
# 방탄소년단
# 베이식 (Basick)
# 임영웅
# 디핵 (D-Hack), PATEKO (파테코)
# 아이유
# Coldplay, 방탄소년단
# 10CM
# V
# 아이유
# 이승윤
# BE'O (비오)
# 비비 (BIBI)
# 먼데이 키즈 (Monday Kiz)
# 호미들
# Ed Sheeran
# 에픽하이 (EPIK HIGH)
# 먼데이 키즈 (Monday Kiz)
# AKMU (악뮤)
# 마크툽 (MAKTUB)
# 헤이즈 (Heize)
# 임영웅
# 경서
# BE'O (비오)
# 방탄소년단
# 이예준
# 폴킴
# 아이유
# AKMU (악뮤)
# 아이유
# 성시경
# Justin Bieber
# 브레이브걸스
# 원슈타인
# 멜로망스
# Kelly Clarkson
# Mudd the student
# 마크툽 (MAKTUB)
# 황인욱
# 방탄소년단
# 이예준
# 개코, 아우릴고트 (OUREALGOAT), SINCE, 안병웅, Tabber, 조광일
# 아넌딜라이트(Anandelight), unofficialboyy, BE'O (비오), 지구인, Mudd the student
# 오마이걸 (OH MY GIRL)
# ...

# %% [markdown]
# ### 곡 리스트 추출

# %%
# 가수 이름만 가져오기
singer = soup.select("div.ellipsis.rank02 > a")
singer[0].text
# Out:
# '태연 (TAEYEON)'

# %%
# 100개 데이터의 제목과 가수이름을 출력해 주세요...
# 출력 형태 : 제목 [INVU], 가수[태연]
for i in range(0, len(songs)) : 

    title = songs[i].select("div.rank01>span>a")[0].text
    singer = songs[i].select("div.rank02>span")[0].text
    print("순위[{}], 제목[{}], 가수[{}]". format((i+1),title, singer))
# Out:
# 순위[1], 제목[INVU], 가수[태연 (TAEYEON)]
# 순위[2], 제목[사랑은 늘 도망가], 가수[임영웅]
# 순위[3], 제목[취중고백], 가수[김민석 (멜로망스)]
# 순위[4], 제목[듣고 싶을까], 가수[MSG워너비(M.O.M)]
# 순위[5], 제목[언제나 사랑해], 가수[케이시 (Kassy)]
# 순위[6], 제목[RUN2U], 가수[STAYC(스테이씨)]
# 순위[7], 제목[abcdefu], 가수[GAYLE]
# 순위[8], 제목[ELEVEN], 가수[IVE (아이브)]
# 순위[9], 제목[너, 너 (N번째 연애 X 휘인 (Whee In))], 가수[휘인 (Whee In)]
# 순위[10], 제목[SMILEY (Feat. BIBI)], 가수[YENA (최예나)]
# 순위[11], 제목[Step Back], 가수[GOT the beat]
# 순위[12], 제목[회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)], 가수[sokodomo]
# 순위[13], 제목[다정히 내 이름을 부르면], 가수[경서예지, 전건호]
# 순위[14], 제목[이제 나만 믿어요], 가수[임영웅]
# 순위[15], 제목[리무진 (Feat. MINO) (Prod. GRAY)], 가수[BE'O (비오)]
# 순위[16], 제목[호랑수월가], 가수[탑현]
# 순위[17], 제목[눈이 오잖아(Feat.헤이즈)], 가수[이무진]
# 순위[18], 제목[신호등], 가수[이무진]
# 순위[19], 제목[STAY], 가수[The Kid LAROI, Justin Bieber]
# 순위[20], 제목[다시 사랑한다면 (김필 Ver.)], 가수[임영웅]
# 순위[21], 제목[Counting Stars (Feat. Beenzino)], 가수[BE'O (비오)]
# 순위[22], 제목[그대라는 사치], 가수[임영웅]
# 순위[23], 제목[어제처럼], 가수[폴킴]
# 순위[24], 제목[별빛 같은 나의 사랑아], 가수[임영웅]
# ...

# %%
driver = webdriver.Chrome("C:/ChromeDriver_exe/chromedriver.exe")

url = "http://www.melon.com/chart/index.htm"
driver.get(url)
soup = BeautifulSoup(html, "html.parser")


# selenium 방식시작....
#find_elements_by_css_selector() 함수 사용
# 순위 10 뽑기
songs= driver.find_elements_by_css_selector("tr")[1 : 11]

for i in range(0, len(songs)): 
    # 노래 제목만 가지고 오기
    title = songs[i].find_elements_by_css_selector("div.rank01>span>a")[0].text
    # 가수 이름만 가지고 오기
    singer = songs[i].find_elements_by_css_selector("div.rank02>span")[0].text
    # 조회
    print("순위[{}], 제목[{}], 가수[{}]". format((i+1),title, singer))
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_13708/318402536.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/ChromeDriver_exe/chromedriver.exe")
# C:\Users\admin\AppData\Local\Temp/ipykernel_13708/318402536.py:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   songs= driver.find_elements_by_css_selector("tr")[1 : 11]
# 순위[1], 제목[INVU], 가수[]
# 순위[2], 제목[사랑은 늘 도망가], 가수[]
# 순위[3], 제목[취중고백], 가수[]
# 순위[4], 제목[듣고 싶을까], 가수[]
# 순위[5], 제목[언제나 사랑해], 가수[]
# 순위[6], 제목[RUN2U], 가수[]
# 순위[7], 제목[abcdefu], 가수[]
# 순위[8], 제목[ELEVEN], 가수[]
# 순위[9], 제목[너, 너 (N번째 연애 X 휘인 (Whee In))], 가수[]
# 순위[10], 제목[SMILEY (Feat. BIBI)], 가수[]

# %%
driver = webdriver.Chrome("C:/ChromeDriver_exe/chromedriver.exe")
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_10556/2815863721.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/ChromeDriver_exe/chromedriver.exe")

# %%
# 웹 url로 접근하기
url = "https://www.donga.ac.kr"
driver.get(url)
