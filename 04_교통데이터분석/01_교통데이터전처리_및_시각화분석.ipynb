# %% [markdown]
# # 컬럼명 한글명으로 변환
# ### - 샘플 trfcard(0)폴더에 있는 파일을 기준으로 우선 변환

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os

# %%
ex0 = pd.read_excel("./01_data_원본/포항시_버스_사용자_교통카드_사용_내역/trfcard (0)/trfcard_columns.xlsx",header=2)

ex0
# Out:
#     구분     컬럼명 (영문)     컬럼명 (한글) Not Null 여부    데이터 타입    길이 PK 정보  FK 정보  \
# 0  NaN      on_date         승차시각           Y  datetime   NaN     Y    NaN
# 1  NaN     off_date         하차시각           Y  datetime   NaN   NaN    NaN
# 2  NaN   route_name          노선명           Y   varchar   100   NaN    NaN
# 3  NaN        descr         노선설명           Y   varchar   100   NaN    NaN
# 4  NaN     age_type         승객연령           Y   varchar    20   NaN    NaN
# 5  NaN     trans_yn         환승여부           Y   varchar     1   NaN    NaN
# 6  NaN    addfee_yn       추가운임여부           Y   varchar     1   NaN    NaN
# 7  NaN  start_bstop        승차정류장           Y   varchar   100   NaN    NaN
# 8  NaN  start_gps_x  승차정류장 GPS X           Y   numeric  10,7   NaN    NaN
# 9  NaN  start_gps_y  승차정류장 GPS Y           Y   numeric  10,7   NaN    NaN
# 10 NaN    end_bstop        하차정류장           Y   varchar   100   NaN    NaN
# 11 NaN    end_gps_x  하차정류장 GPS X           Y   numeric  10,7   NaN    NaN
# ...

# %%
csv0 = pd.read_csv 
("./01_data_원본/포항시_버스_사용자_교통카드_사용_내역/trfcard (0)/trfcard.csv")
csv0
# Out:
# <function pandas.io.parsers.readers.read_csv(filepath_or_buffer: 'FilePathOrBuffer', sep=<no_default>, delimiter=None, header='infer', names=<no_default>, index_col=None, usecols=None, squeeze=False, prefix=<no_default>, mangle_dupe_cols=True, dtype: 'DtypeArg | None' = None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal: 'str' = '.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, encoding_errors: 'str | None' = 'strict', dialect=None, error_bad_lines=None, warn_bad_lines=None, on_bad_lines=None, delim_whitespace=False, low_memory=True, memory_map=Fals
# ...

# %%
list0 = ex0["컬럼명 (한글)"]
list0
# Out:
# 0            승차시각
# 1            하차시각
# 2             노선명
# 3            노선설명
# 4            승객연령
# 5            환승여부
# 6          추가운임여부
# 7           승차정류장
# 8     승차정류장 GPS X
# 9     승차정류장 GPS Y
# 10          하차정류장
# 11    하차정류장 GPS X
# 12    하차정류장 GPS Y
# Name: 컬럼명 (한글), dtype: object

# %%
csv0.columns=[(list0)]
csv0
# Out:
# <function pandas.io.parsers.readers.read_csv(filepath_or_buffer: 'FilePathOrBuffer', sep=<no_default>, delimiter=None, header='infer', names=<no_default>, index_col=None, usecols=None, squeeze=False, prefix=<no_default>, mangle_dupe_cols=True, dtype: 'DtypeArg | None' = None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal: 'str' = '.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, encoding_errors: 'str | None' = 'strict', dialect=None, error_bad_lines=None, warn_bad_lines=None, on_bad_lines=None, delim_whitespace=False, low_memory=True, memory_map=Fals
# ...

# %%
ex0 = pd.read_excel("./01_data_원본/포항시_버스_사용자_교통카드_사용_내역/trfcard (0)/trfcard_columns.xlsx",header=2)

csv0 = pd.read_csv \
("./01_data_원본/포항시_버스_사용자_교통카드_사용_내역/trfcard (0)/trfcard.csv")

list0 =ex0["컬럼명 (한글)"]

csv0.columns=[(list0)]
csv0
# Out:
# 컬럼명 (한글)            승차시각            하차시각  노선명               노선설명 승객연령 환승여부  \
# 0         20200327051412  20200327051714  160     문덕-대송-송도-죽도-용흥   일반    N
# 1         20200327051514  20200327054956  175   문덕-고속터미널-선린병원-달전   일반    N
# 2         20200327052343  20200327054659  200    양덕-남구청(야구장)-구룡포   일반    N
# 3         20200327052449  20200327055412  100           문덕-흥해-신광   일반    N
# 4         20200327052848  20200327055231  175   문덕-고속터미널-선린병원-달전   일반    N
# ...                  ...             ...  ...                ...  ...  ...
# 4978      20200327232513  20200327232800  101        양덕-고속터미널-동해   일반    Y
# 4979      20200327232740  20200327233319  107    문덕-시외(고속)터미널-흥해   일반    N
# 4980      20200327232829  20200327233446  500  문덕-시외터미널-흥해-청하-월포   일반    N
# 4981      20200327233328  20200327233442  107    문덕-시외(고속)터미널-흥해   일반    N
# 4982      20200327233622  20200327234014  105        양덕-시외터미널-지곡   일반    N
#
# ...
